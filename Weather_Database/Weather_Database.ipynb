# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 747

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | kuching
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | fairbanks
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | ixtapa
# Processing Record 8 of Set 1 | manadhoo
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | teya
# Processing Record 14 of Set 1 | ishigaki
# Processing Record 15 of Set 1 | necochea
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | codrington
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | rio gallegos
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | puerto princesa
# Processing Record 27 of Set 1 | adzhamka
# Processing Record 28 of Set 1 | malartic
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | honningsvag
# Processing Record 32 of Set 1 | kautokeino
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | barranca
# Processing Record 35 of Set 1 | les cayes
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | port lincoln
# Processing Record 39 of Set 1 | qingyuan
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | honiara
# Processing Record 43 of Set 1 | elban
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | bubaque
# Processing Record 46 of Set 1 | neepawa
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | cockburn town
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | aykhal
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | lavrentiya
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | nurota
# Processing Record 5 of Set 2 | murgab
# Processing Record 6 of Set 2 | vao
# Processing Record 7 of Set 2 | poum
# Processing Record 8 of Set 2 | lafia
# Processing Record 9 of Set 2 | saldanha
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | shenjiamen
# Processing Record 16 of Set 2 | naze
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | benque viejo
# City not found. Skipping...
# Processing Record 19 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 2 | luangwa
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | zhigansk
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | puerto el triunfo
# Processing Record 26 of Set 2 | kuandian
# Processing Record 27 of Set 2 | lingyuan
# Processing Record 28 of Set 2 | rabo de peixe
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | najran
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 2 | bathsheba
# Processing Record 36 of Set 2 | ciras
# City not found. Skipping...
# Processing Record 37 of Set 2 | college
# Processing Record 38 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 2 | portsmouth
# Processing Record 40 of Set 2 | fort nelson
# Processing Record 41 of Set 2 | pitimbu
# Processing Record 42 of Set 2 | alice springs
# Processing Record 43 of Set 2 | mount gambier
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | ust-kalmanka
# Processing Record 46 of Set 2 | carballo
# Processing Record 47 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 48 of Set 2 | phek
# Processing Record 49 of Set 2 | acarau
# Processing Record 50 of Set 2 | cartagena
# Processing Record 1 of Set 3 | nizwa
# Processing Record 2 of Set 3 | alofi
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | colomi
# Processing Record 5 of Set 3 | iqaluit
# Processing Record 6 of Set 3 | katherine
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | merritt
# Processing Record 9 of Set 3 | kendari
# Processing Record 10 of Set 3 | hermanus
# Processing Record 11 of Set 3 | sarmanovo
# Processing Record 12 of Set 3 | balkhash
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | high level
# Processing Record 15 of Set 3 | jalu
# Processing Record 16 of Set 3 | komsomolskiy
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | leningradskiy
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | ipira
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | takoradi
# Processing Record 24 of Set 3 | ayame
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | new norfolk
# Processing Record 27 of Set 3 | adelaide
# Processing Record 28 of Set 3 | de-kastri
# Processing Record 29 of Set 3 | kavaratti
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | concarneau
# Processing Record 32 of Set 3 | georgetown
# Processing Record 33 of Set 3 | vardo
# Processing Record 34 of Set 3 | igarka
# Processing Record 35 of Set 3 | rogaska slatina
# Processing Record 36 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | sainte-marie
# Processing Record 41 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | bengkulu
# Processing Record 44 of Set 3 | mahebourg
# Processing Record 45 of Set 3 | omaruru
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | tahe
# Processing Record 48 of Set 3 | kalmunai
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | cayenne
# Processing Record 1 of Set 4 | boali
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 4 of Set 4 | namatanai
# Processing Record 5 of Set 4 | timberlake
# Processing Record 6 of Set 4 | luderitz
# Processing Record 7 of Set 4 | tucuma
# Processing Record 8 of Set 4 | kununurra
# Processing Record 9 of Set 4 | quelimane
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | borovoy
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | severo-yeniseyskiy
# Processing Record 15 of Set 4 | cordoba
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | henties bay
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | port hardy
# Processing Record 20 of Set 4 | dunedin
# Processing Record 21 of Set 4 | aksarka
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | camabatela
# Processing Record 24 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 25 of Set 4 | mnogovershinnyy
# Processing Record 26 of Set 4 | igrim
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | vokhma
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | giyani
# Processing Record 31 of Set 4 | northam
# Processing Record 32 of Set 4 | luyang
# Processing Record 33 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | palmer
# Processing Record 36 of Set 4 | norman wells
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | ha tinh
# Processing Record 40 of Set 4 | walvis bay
# Processing Record 41 of Set 4 | suntar
# Processing Record 42 of Set 4 | kuzovatovo
# Processing Record 43 of Set 4 | sven
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | tilichiki
# Processing Record 46 of Set 4 | makakilo city
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | veseloyarsk
# Processing Record 49 of Set 4 | chivolo
# Processing Record 50 of Set 4 | tevaitoa
# Processing Record 1 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 5 | hongjiang
# Processing Record 3 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 5 of Set 5 | sambava
# Processing Record 6 of Set 5 | kaitangata
# Processing Record 7 of Set 5 | moindou
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | buraydah
# Processing Record 10 of Set 5 | iquique
# Processing Record 11 of Set 5 | keningau
# Processing Record 12 of Set 5 | sechura
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | marawi
# Processing Record 15 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 5 | lenger
# Processing Record 17 of Set 5 | ola
# Processing Record 18 of Set 5 | panguipulli
# Processing Record 19 of Set 5 | labuhan
# Processing Record 20 of Set 5 | santa cruz
# Processing Record 21 of Set 5 | harper
# Processing Record 22 of Set 5 | saquena
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | havoysund
# Processing Record 25 of Set 5 | langham
# Processing Record 26 of Set 5 | torbay
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | sokoni
# Processing Record 29 of Set 5 | verkh-usugli
# Processing Record 30 of Set 5 | dera bugti
# Processing Record 31 of Set 5 | lasa
# Processing Record 32 of Set 5 | yamada
# Processing Record 33 of Set 5 | port augusta
# Processing Record 34 of Set 5 | vila franca do campo
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | coquimbo
# Processing Record 37 of Set 5 | goderich
# Processing Record 38 of Set 5 | nanortalik
# Processing Record 39 of Set 5 | bam
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | san carlos
# Processing Record 42 of Set 5 | contamana
# Processing Record 43 of Set 5 | chokurdakh
# Processing Record 44 of Set 5 | baykit
# Processing Record 45 of Set 5 | arklow
# Processing Record 46 of Set 5 | pokhara
# Processing Record 47 of Set 5 | sarakhs
# Processing Record 48 of Set 5 | ulladulla
# Processing Record 49 of Set 5 | pandan
# Processing Record 50 of Set 5 | havre
# Processing Record 1 of Set 6 | abu dhabi
# Processing Record 2 of Set 6 | santa isabel
# Processing Record 3 of Set 6 | kirkwall
# Processing Record 4 of Set 6 | iranshahr
# Processing Record 5 of Set 6 | mugan
# Processing Record 6 of Set 6 | kutum
# Processing Record 7 of Set 6 | zhezkazgan
# Processing Record 8 of Set 6 | kimberley
# Processing Record 9 of Set 6 | matao
# Processing Record 10 of Set 6 | padang
# Processing Record 11 of Set 6 | inta
# Processing Record 12 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 6 | tchibanga
# Processing Record 14 of Set 6 | urumqi
# Processing Record 15 of Set 6 | berlevag
# Processing Record 16 of Set 6 | canoa
# Processing Record 17 of Set 6 | chenzhou
# Processing Record 18 of Set 6 | xuanwu
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | puerto carreno
# Processing Record 22 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | mwanza
# Processing Record 24 of Set 6 | shugurovo
# Processing Record 25 of Set 6 | grindavik
# Processing Record 26 of Set 6 | amga
# Processing Record 27 of Set 6 | hamilton
# Processing Record 28 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 29 of Set 6 | lagoa
# Processing Record 30 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 6 | poya
# Processing Record 32 of Set 6 | san cristobal
# Processing Record 33 of Set 6 | natal
# Processing Record 34 of Set 6 | dharmapuri
# Processing Record 35 of Set 6 | finspang
# Processing Record 36 of Set 6 | gat
# Processing Record 37 of Set 6 | adrar
# Processing Record 38 of Set 6 | mamallapuram
# Processing Record 39 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 6 | tadine
# Processing Record 41 of Set 6 | bereda
# Processing Record 42 of Set 6 | sungurlu
# Processing Record 43 of Set 6 | miles city
# Processing Record 44 of Set 6 | mitsamiouli
# Processing Record 45 of Set 6 | sao jose da coroa grande
# Processing Record 46 of Set 6 | caravelas
# Processing Record 47 of Set 6 | meise
# Processing Record 48 of Set 6 | talbahat
# Processing Record 49 of Set 6 | cape town
# Processing Record 50 of Set 6 | vila do maio
# Processing Record 1 of Set 7 | bourail
# Processing Record 2 of Set 7 | oussouye
# Processing Record 3 of Set 7 | buala
# Processing Record 4 of Set 7 | trelew
# Processing Record 5 of Set 7 | kangaba
# Processing Record 6 of Set 7 | aklavik
# Processing Record 7 of Set 7 | akdepe
# Processing Record 8 of Set 7 | paamiut
# Processing Record 9 of Set 7 | dali
# Processing Record 10 of Set 7 | hinton
# Processing Record 11 of Set 7 | kota bahru
# Processing Record 12 of Set 7 | zhangye
# Processing Record 13 of Set 7 | asau
# Processing Record 14 of Set 7 | fonte boa
# Processing Record 15 of Set 7 | itoman
# Processing Record 16 of Set 7 | sola
# Processing Record 17 of Set 7 | kajaani
# Processing Record 18 of Set 7 | astana
# Processing Record 19 of Set 7 | qinhuangdao
# Processing Record 20 of Set 7 | san patricio
# Processing Record 21 of Set 7 | hun
# Processing Record 22 of Set 7 | bar harbor
# Processing Record 23 of Set 7 | waipawa
# Processing Record 24 of Set 7 | monrovia
# Processing Record 25 of Set 7 | husavik
# Processing Record 26 of Set 7 | tasiilaq
# Processing Record 27 of Set 7 | victoria
# Processing Record 28 of Set 7 | athabasca
# Processing Record 29 of Set 7 | kahului
# Processing Record 30 of Set 7 | chuy
# Processing Record 31 of Set 7 | maracaibo
# Processing Record 32 of Set 7 | sabancuy
# Processing Record 33 of Set 7 | miandoab
# Processing Record 34 of Set 7 | warrington
# Processing Record 35 of Set 7 | kangaatsiaq
# Processing Record 36 of Set 7 | ayagoz
# Processing Record 37 of Set 7 | vredendal
# Processing Record 38 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 39 of Set 7 | waco
# Processing Record 40 of Set 7 | ambilobe
# Processing Record 41 of Set 7 | helena
# Processing Record 42 of Set 7 | fortuna
# Processing Record 43 of Set 7 | calama
# Processing Record 44 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 7 | polyarnyy
# Processing Record 46 of Set 7 | nanzhang
# Processing Record 47 of Set 7 | lorengau
# Processing Record 48 of Set 7 | nemuro
# Processing Record 49 of Set 7 | kobelyaky
# Processing Record 50 of Set 7 | marsa matruh
# Processing Record 1 of Set 8 | constitucion
# Processing Record 2 of Set 8 | starkville
# Processing Record 3 of Set 8 | sobolevo
# Processing Record 4 of Set 8 | road town
# Processing Record 5 of Set 8 | shache
# Processing Record 6 of Set 8 | novopokrovka
# Processing Record 7 of Set 8 | mangan
# Processing Record 8 of Set 8 | gazanjyk
# Processing Record 9 of Set 8 | hovd
# Processing Record 10 of Set 8 | opuwo
# Processing Record 11 of Set 8 | lom sak
# Processing Record 12 of Set 8 | haines junction
# Processing Record 13 of Set 8 | saskylakh
# Processing Record 14 of Set 8 | hambantota
# Processing Record 15 of Set 8 | finnsnes
# Processing Record 16 of Set 8 | general roca
# Processing Record 17 of Set 8 | san policarpo
# Processing Record 18 of Set 8 | arroio grande
# Processing Record 19 of Set 8 | prince rupert
# Processing Record 20 of Set 8 | asfi
# Processing Record 21 of Set 8 | wana
# Processing Record 22 of Set 8 | emerald
# Processing Record 23 of Set 8 | csorna
# Processing Record 24 of Set 8 | rosetta
# Processing Record 25 of Set 8 | la paz
# Processing Record 26 of Set 8 | grand gaube
# Processing Record 27 of Set 8 | pachino
# Processing Record 28 of Set 8 | poronaysk
# Processing Record 29 of Set 8 | cardston
# Processing Record 30 of Set 8 | morondava
# Processing Record 31 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | dubbo
# Processing Record 33 of Set 8 | malakal
# Processing Record 34 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 8 | ouesso
# Processing Record 36 of Set 8 | sao joao
# Processing Record 37 of Set 8 | ust-kuyga
# Processing Record 38 of Set 8 | estelle
# Processing Record 39 of Set 8 | vilcun
# Processing Record 40 of Set 8 | gamba
# Processing Record 41 of Set 8 | burica
# City not found. Skipping...
# Processing Record 42 of Set 8 | portland
# Processing Record 43 of Set 8 | melilla
# Processing Record 44 of Set 8 | karasjok
# Processing Record 45 of Set 8 | dekar
# Processing Record 46 of Set 8 | carutapera
# Processing Record 47 of Set 8 | ilebo
# Processing Record 48 of Set 8 | gushikawa
# Processing Record 49 of Set 8 | trogir
# Processing Record 50 of Set 8 | nhulunbuy
# Processing Record 1 of Set 9 | port-gentil
# Processing Record 2 of Set 9 | tuy hoa
# Processing Record 3 of Set 9 | siocon
# Processing Record 4 of Set 9 | porto santo
# Processing Record 5 of Set 9 | riviere-au-renard
# Processing Record 6 of Set 9 | ferrol
# Processing Record 7 of Set 9 | balykshi
# Processing Record 8 of Set 9 | north adams
# Processing Record 9 of Set 9 | lugovskoy
# Processing Record 10 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 9 | chazuta
# Processing Record 12 of Set 9 | miri
# Processing Record 13 of Set 9 | kipini
# Processing Record 14 of Set 9 | atbasar
# Processing Record 15 of Set 9 | oyonnax
# Processing Record 16 of Set 9 | maksatikha
# Processing Record 17 of Set 9 | litovko
# Processing Record 18 of Set 9 | mahanoro
# Processing Record 19 of Set 9 | tazmalt
# Processing Record 20 of Set 9 | sadove
# Processing Record 21 of Set 9 | gary
# Processing Record 22 of Set 9 | gua musang
# Processing Record 23 of Set 9 | richards bay
# Processing Record 24 of Set 9 | cukai
# Processing Record 25 of Set 9 | dukat
# Processing Record 26 of Set 9 | mpraeso
# Processing Record 27 of Set 9 | pangnirtung
# Processing Record 28 of Set 9 | capinota
# Processing Record 29 of Set 9 | lima
# Processing Record 30 of Set 9 | boysun
# Processing Record 31 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 32 of Set 9 | jimenez
# Processing Record 33 of Set 9 | ponta do sol
# Processing Record 34 of Set 9 | willowmore
# Processing Record 35 of Set 9 | covington
# Processing Record 36 of Set 9 | noyon
# Processing Record 37 of Set 9 | hvolsvollur
# Processing Record 38 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 9 | sauk rapids
# Processing Record 40 of Set 9 | chicama
# Processing Record 41 of Set 9 | rehoboth
# Processing Record 42 of Set 9 | morant bay
# Processing Record 43 of Set 9 | camacha
# Processing Record 44 of Set 9 | awbari
# Processing Record 45 of Set 9 | bandiagara
# Processing Record 46 of Set 9 | alibag
# Processing Record 47 of Set 9 | rundu
# Processing Record 48 of Set 9 | kindu
# Processing Record 49 of Set 9 | zhoucheng
# Processing Record 50 of Set 9 | botou
# Processing Record 1 of Set 10 | linxia
# Processing Record 2 of Set 10 | nelson bay
# Processing Record 3 of Set 10 | buinsk
# Processing Record 4 of Set 10 | wanaka
# Processing Record 5 of Set 10 | palm beach
# Processing Record 6 of Set 10 | viytivka
# Processing Record 7 of Set 10 | ponta pora
# Processing Record 8 of Set 10 | anadyr
# Processing Record 9 of Set 10 | camara de lobos
# Processing Record 10 of Set 10 | ler
# Processing Record 11 of Set 10 | point fortin
# Processing Record 12 of Set 10 | saint-leu
# Processing Record 13 of Set 10 | viedma
# Processing Record 14 of Set 10 | liverpool
# Processing Record 15 of Set 10 | ravar
# Processing Record 16 of Set 10 | rakke
# Processing Record 17 of Set 10 | vagur
# Processing Record 18 of Set 10 | porto walter
# Processing Record 19 of Set 10 | avera
# Processing Record 20 of Set 10 | bojnurd
# Processing Record 21 of Set 10 | pangody
# Processing Record 22 of Set 10 | bereznik
# Processing Record 23 of Set 10 | namibe
# Processing Record 24 of Set 10 | pakisaji
# Processing Record 25 of Set 10 | puerto ayacucho
# Processing Record 26 of Set 10 | crotone
# Processing Record 27 of Set 10 | eskisehir
# Processing Record 28 of Set 10 | gazni
# City not found. Skipping...
# Processing Record 29 of Set 10 | tocopilla
# Processing Record 30 of Set 10 | todos santos
# Processing Record 31 of Set 10 | rawatsar
# Processing Record 32 of Set 10 | jaciara
# Processing Record 33 of Set 10 | emet
# Processing Record 34 of Set 10 | westport
# Processing Record 35 of Set 10 | obo
# Processing Record 36 of Set 10 | awjilah
# Processing Record 37 of Set 10 | koutsouras
# Processing Record 38 of Set 10 | sakakah
# Processing Record 39 of Set 10 | lebork
# Processing Record 40 of Set 10 | katsuura
# Processing Record 41 of Set 10 | champerico
# Processing Record 42 of Set 10 | harwich
# Processing Record 43 of Set 10 | spassk
# Processing Record 44 of Set 10 | plyussa
# Processing Record 45 of Set 10 | sigli
# Processing Record 46 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 10 | acari
# Processing Record 48 of Set 10 | wani
# Processing Record 49 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 50 of Set 10 | saryg-sep
# Processing Record 1 of Set 11 | ossora
# Processing Record 2 of Set 11 | aljezur
# Processing Record 3 of Set 11 | dogondoutchi
# Processing Record 4 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 11 | conway
# Processing Record 6 of Set 11 | zilair
# Processing Record 7 of Set 11 | werda
# Processing Record 8 of Set 11 | kigali
# Processing Record 9 of Set 11 | hearst
# Processing Record 10 of Set 11 | kamina
# Processing Record 11 of Set 11 | ewa beach
# Processing Record 12 of Set 11 | yumen
# Processing Record 13 of Set 11 | sucua
# Processing Record 14 of Set 11 | la ronge
# Processing Record 15 of Set 11 | laredo
# Processing Record 16 of Set 11 | kiruna
# Processing Record 17 of Set 11 | ayan
# Processing Record 18 of Set 11 | kruisfontein
# Processing Record 19 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 11 | strezhevoy
# Processing Record 21 of Set 11 | atar
# Processing Record 22 of Set 11 | kenitra
# Processing Record 23 of Set 11 | kouango
# Processing Record 24 of Set 11 | lata
# Processing Record 25 of Set 11 | mehriz
# Processing Record 26 of Set 11 | talnakh
# Processing Record 27 of Set 11 | letlhakane
# Processing Record 28 of Set 11 | konevo
# Processing Record 29 of Set 11 | dingle
# Processing Record 30 of Set 11 | cam ranh
# Processing Record 31 of Set 11 | tashla
# Processing Record 32 of Set 11 | mezotur
# Processing Record 33 of Set 11 | tura
# Processing Record 34 of Set 11 | remedios
# Processing Record 35 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 11 | borzya
# Processing Record 37 of Set 11 | kirakira
# Processing Record 38 of Set 11 | kysyl-syr
# Processing Record 39 of Set 11 | eyemouth
# Processing Record 40 of Set 11 | gofitskoye
# Processing Record 41 of Set 11 | bilma
# Processing Record 42 of Set 11 | tatvan
# Processing Record 43 of Set 11 | keti bandar
# Processing Record 44 of Set 11 | kidal
# Processing Record 45 of Set 11 | darhan
# Processing Record 46 of Set 11 | saint anthony
# Processing Record 47 of Set 11 | tucumcari
# Processing Record 48 of Set 11 | sur
# Processing Record 49 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 50 of Set 11 | la gaulette
# City not found. Skipping...
# Processing Record 1 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 12 | saint-augustin
# Processing Record 3 of Set 12 | letlhakeng
# Processing Record 4 of Set 12 | zaysan
# Processing Record 5 of Set 12 | bongandanga
# Processing Record 6 of Set 12 | synya
# Processing Record 7 of Set 12 | coihaique
# Processing Record 8 of Set 12 | mayor pablo lagerenza
# Processing Record 9 of Set 12 | kholodnyy
# Processing Record 10 of Set 12 | calobre
# City not found. Skipping...
# Processing Record 11 of Set 12 | nchelenge
# Processing Record 12 of Set 12 | kyzyl-mazhalyk
# Processing Record 13 of Set 12 | mundo nuevo
# Processing Record 14 of Set 12 | bandarbeyla
# Processing Record 15 of Set 12 | margate
# Processing Record 16 of Set 12 | sibolga
# Processing Record 17 of Set 12 | sosva
# Processing Record 18 of Set 12 | alyangula
# Processing Record 19 of Set 12 | borogontsy
# Processing Record 20 of Set 12 | pattoki
# Processing Record 21 of Set 12 | arlit
# Processing Record 22 of Set 12 | itarema
# Processing Record 23 of Set 12 | tornio
# Processing Record 24 of Set 12 | whitehorse
# Processing Record 25 of Set 12 | gornopravdinsk
# Processing Record 26 of Set 12 | kintampo
# Processing Record 27 of Set 12 | maturin
# Processing Record 28 of Set 12 | bodden town
# Processing Record 29 of Set 12 | hami
# Processing Record 30 of Set 12 | aksu
# Processing Record 31 of Set 12 | morro bay
# Processing Record 32 of Set 12 | saint paul
# Processing Record 33 of Set 12 | yulara
# Processing Record 34 of Set 12 | nichinan
# Processing Record 35 of Set 12 | svetlogorsk
# Processing Record 36 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 12 | beirut
# Processing Record 38 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 12 | orativ
# Processing Record 40 of Set 12 | chapais
# Processing Record 41 of Set 12 | yershichi
# Processing Record 42 of Set 12 | palmeira
# Processing Record 43 of Set 12 | thunder bay
# Processing Record 44 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 12 | nahrin
# Processing Record 46 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 47 of Set 12 | galeana
# Processing Record 48 of Set 12 | enid
# Processing Record 49 of Set 12 | praya
# Processing Record 50 of Set 12 | ustye
# Processing Record 1 of Set 13 | matara
# Processing Record 2 of Set 13 | saint-joseph
# Processing Record 3 of Set 13 | umm kaddadah
# Processing Record 4 of Set 13 | tiarei
# Processing Record 5 of Set 13 | vitim
# Processing Record 6 of Set 13 | brownfield
# Processing Record 7 of Set 13 | kolosovka
# Processing Record 8 of Set 13 | half moon bay
# Processing Record 9 of Set 13 | mandera
# Processing Record 10 of Set 13 | jijiga
# Processing Record 11 of Set 13 | mareeba
# Processing Record 12 of Set 13 | gouyave
# Processing Record 13 of Set 13 | pinawa
# Processing Record 14 of Set 13 | raga
# Processing Record 15 of Set 13 | meulaboh
# Processing Record 16 of Set 13 | apatou
# Processing Record 17 of Set 13 | laguna
# Processing Record 18 of Set 13 | palana
# Processing Record 19 of Set 13 | koumac
# Processing Record 20 of Set 13 | pekan
# Processing Record 21 of Set 13 | zyryanskoye
# Processing Record 22 of Set 13 | wawa
# Processing Record 23 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 13 | krieglach
# Processing Record 25 of Set 13 | almenevo
# City not found. Skipping...
# Processing Record 26 of Set 13 | fare
# Processing Record 27 of Set 13 | brooks
# Processing Record 28 of Set 13 | khor
# Processing Record 29 of Set 13 | varhaug
# Processing Record 30 of Set 13 | akdagmadeni
# Processing Record 31 of Set 13 | campo formoso
# Processing Record 32 of Set 13 | gobabis
# Processing Record 33 of Set 13 | pailon
# Processing Record 34 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 35 of Set 13 | tarakan
# Processing Record 36 of Set 13 | kamaishi
# Processing Record 37 of Set 13 | merauke
# Processing Record 38 of Set 13 | tucuman
# Processing Record 39 of Set 13 | markova
# Processing Record 40 of Set 13 | oranjemund
# Processing Record 41 of Set 13 | det udom
# Processing Record 42 of Set 13 | heusden
# Processing Record 43 of Set 13 | mbumi
# Processing Record 44 of Set 13 | ostrovnoy
# Processing Record 45 of Set 13 | kloulklubed
# Processing Record 46 of Set 13 | monforte de lemos
# Processing Record 47 of Set 13 | chiang kham
# Processing Record 48 of Set 13 | saurimo
# Processing Record 49 of Set 13 | yarim
# Processing Record 50 of Set 13 | khani
# Processing Record 1 of Set 14 | lerwick
# Processing Record 2 of Set 14 | oktyabrskiy
# Processing Record 3 of Set 14 | sarangani
# Processing Record 4 of Set 14 | castanos
# Processing Record 5 of Set 14 | burnie
# Processing Record 6 of Set 14 | sri aman
# Processing Record 7 of Set 14 | zagreb
# Processing Record 8 of Set 14 | lodja
# Processing Record 9 of Set 14 | acapulco
# Processing Record 10 of Set 14 | kimi
# City not found. Skipping...
# Processing Record 11 of Set 14 | biak
# Processing Record 12 of Set 14 | ushtobe
# Processing Record 13 of Set 14 | araguatins
# City not found. Skipping...
# Processing Record 14 of Set 14 | taltal
# Processing Record 15 of Set 14 | mogadishu
# Processing Record 16 of Set 14 | bidar
# Processing Record 17 of Set 14 | outjo
# Processing Record 18 of Set 14 | sabang
# Processing Record 19 of Set 14 | marsaxlokk
# Processing Record 20 of Set 14 | korla
# Processing Record 21 of Set 14 | baruun-urt
# Processing Record 22 of Set 14 | roma
# Processing Record 23 of Set 14 | surt
# Processing Record 24 of Set 14 | cape canaveral
# Processing Record 25 of Set 14 | anlu
# Processing Record 26 of Set 14 | calatayud
# Processing Record 27 of Set 14 | seredka
# Processing Record 28 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 29 of Set 14 | olafsvik
# Processing Record 30 of Set 14 | mahibadhoo
# Processing Record 31 of Set 14 | khash
# Processing Record 32 of Set 14 | talcahuano
# Processing Record 33 of Set 14 | wakkanai
# Processing Record 34 of Set 14 | kailua
# Processing Record 35 of Set 14 | hueyotlipan
# Processing Record 36 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 14 | dongli
# Processing Record 39 of Set 14 | nguruka
# Processing Record 40 of Set 14 | yinchuan
# Processing Record 41 of Set 14 | virginia beach
# Processing Record 42 of Set 14 | marzuq
# Processing Record 43 of Set 14 | lemesos
# City not found. Skipping...
# Processing Record 44 of Set 14 | little current
# Processing Record 45 of Set 14 | yarovoye
# Processing Record 46 of Set 14 | mehamn
# Processing Record 47 of Set 14 | taoudenni
# Processing Record 48 of Set 14 | valente
# Processing Record 49 of Set 14 | nantucket
# Processing Record 50 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 15 | lakes entrance
# Processing Record 2 of Set 15 | hereford
# Processing Record 3 of Set 15 | broome
# Processing Record 4 of Set 15 | russell
# Processing Record 5 of Set 15 | queanbeyan
# Processing Record 6 of Set 15 | tuxpan
# Processing Record 7 of Set 15 | maniitsoq
# Processing Record 8 of Set 15 | moose factory
# Processing Record 9 of Set 15 | waseca
# Processing Record 10 of Set 15 | isangel
# Processing Record 11 of Set 15 | kaeo
# Processing Record 12 of Set 15 | luanda
# Processing Record 13 of Set 15 | kungsbacka
# Processing Record 14 of Set 15 | ketchikan
# Processing Record 15 of Set 15 | guerrero negro
# Processing Record 16 of Set 15 | san rafael
# Processing Record 17 of Set 15 | lakshmipur
# Processing Record 18 of Set 15 | berdigestyakh
# Processing Record 19 of Set 15 | tyukhtet
# Processing Record 20 of Set 15 | barmer
# Processing Record 21 of Set 15 | sapulpa
# Processing Record 22 of Set 15 | shieli
# Processing Record 23 of Set 15 | gambela
# Processing Record 24 of Set 15 | paris
# Processing Record 25 of Set 15 | hualmay
# Processing Record 26 of Set 15 | aswan
# Processing Record 27 of Set 15 | soyo
# Processing Record 28 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 15 | springfield
# Processing Record 30 of Set 15 | mexico
# Processing Record 31 of Set 15 | bloomfield
# Processing Record 32 of Set 15 | santa rosa
# Processing Record 33 of Set 15 | nabire
# Processing Record 34 of Set 15 | port-cartier
# Processing Record 35 of Set 15 | a
# City not found. Skipping...
# Processing Record 36 of Set 15 | ayorou
# Processing Record 37 of Set 15 | sarab
# Processing Record 38 of Set 15 | pouebo
# Processing Record 39 of Set 15 | kollam
# Processing Record 40 of Set 15 | tsurugi
# Processing Record 41 of Set 15 | masumbwe
# Processing Record 42 of Set 15 | maldonado
# Processing Record 43 of Set 15 | terra santa
# Processing Record 44 of Set 15 | male
# Processing Record 45 of Set 15 | shu
# Processing Record 46 of Set 15 | waycross
# Processing Record 47 of Set 15 | mangrol
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     61.03        85          82
# 1         Kuching      MY   1.5500  110.3333     82.62        78          20
# 2         Ushuaia      AR -54.8000  -68.3000     33.46        86          75
# 3         Rikitea      PF -23.1203 -134.9692     74.75        80          98
# 4       Fairbanks      US  64.8378 -147.7164     71.94        48          20
# 5          Albany      US  42.6001  -73.9662     72.21        81           0
# 6          Ixtapa      MX  20.7000 -105.2000     85.23        74          20
# 7        Manadhoo      MV   5.7667   73.3833     81.99        76         100
# 8          Narsaq      GL  60.9167  -46.0500     52.02        73          73
# 9       Carnarvon      AU -24.8667  113.6333     69.87        64          40
#
#    Wind Speed Current Description
# 0        8.21       broken clouds
# 1        0.00          few clouds
# 2        3.44          light snow
# 3       17.38     overcast clouds
# 4       14.97          few clouds
# 5        5.35           clear sky
# 6        5.75          few clouds
# 7       14.92     overcast clouds
# 8        1.90       broken clouds
# 9       13.80    scattered clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
